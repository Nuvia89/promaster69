# %%
import numpy as np
arraypro = np.array([1,2,3,4])
for ele in arraypro:
print(ele**2)

texto = "Datos"
lista = [1, 2, 3]
arreglo = np.array([4, 5, 6])
# String
for letra in texto:
print("Letra:", letra)
# Lista
for elemento in lista:
print("Lista:", elemento + 1)
# Arreglo
for valor in arreglo:
print("Arreglo:", valor * 2)
# Out:
#   Cell In[31], line 4
#     print(ele**2)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
text="python"
for letra in text:
    print (letra)
    print (type(letra))
# Out:
# p
# <class 'str'>
# y
# <class 'str'>
# t
# <class 'str'>
# h
# <class 'str'>
# o
# <class 'str'>
# n
# <class 'str'>

# %%
numeros = (10,20,30,40)

for num in numeros:
     print (num)

for i in range(4,10):
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 4
# 5
# 6
# 7
# 8
# 9
