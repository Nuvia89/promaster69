# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

datos=[]
#format string
for i in range(1, 5):
    data= np.loadtxt(f'dataset{1}.txt')
    datos.append(data)

c0_ds1=datos[0][:,0]
c1_ds1=datos[0][:,1]

c0_ds2=datos[1][:,0]
c1_ds2=datos[1][:,1]

c0_ds3=datos[2][:,0]
c1_ds3=datos[2][:,1]

c0_ds4=datos[3][:,0]
c1_ds4=datos[3][:,1]

#Dimensiones
n1=min(len(c0_ds1),len(c1_ds1),len(c0_ds2),len(c1_ds2),len(c0_ds3),len(c1_ds3),len(c0_ds4),len(c1_ds4))
