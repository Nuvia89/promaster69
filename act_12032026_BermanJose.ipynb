# %%
nombre="Nuvix"
apellido="Lilmex"
type(nombre)
# Out:
# str

# %%
nombre_completo = nombre+" "+ apellido
print(nombre_completo)
# Out:
# Nuvix Lilmex

# %%
nombre2=nombre_completo*3
print(nombre2)
'Nuvix' in nombre2
# Out:
# Nuvix LilmexNuvix LilmexNuvix Lilmex
# True

# %%
carac=nombre_completo[4]
print(carac)
# Out:
# x

# %%
len(nombre_completo)
len("Hola")
# Out:
# 4

# %%
texto="python"
parte = texto[0:3]
parte
# Out:
# 'pyt'

# %%
sec=texto[0::4]
sec
# Out:
# 'po'

# %%
print(texto)
# Out:
# python

# %%
Lista_1=[1,2,3,4,5,6,7,8, "Hola", "IMNUVIX", 8+4]
type(Lista_1[-1])
# Out:
# int
