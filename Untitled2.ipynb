# %%
numeros = [1,2,43,5,3,6,4,6,7,4,3,2,56,7,6,4,1]
len (numeros)
# Out:
# 17

# %%
minimo = min(numeros)
minimo
# Out:
# 1

# %%
maximo=max(numeros)
maximo
# Out:
# 56

# %%
suma_lista=sum(numeros)
suma_lista
# Out:
# 160

# %%
promedio_lista=suma_lista/len(numeros)
promedio_lista
# Out:
# 9.411764705882353

# %%
numeros_2=[]
numeros_2.append(10)
numeros_2
numeros_2.append(0)
numeros_2
numeros_2.append(10)
numeros_2
numeros_2.append(100)
numeros_2.append(1000)
numeros_2
# Out:
# [10, 0, 10, 100, 1000]

# %%
numeros_2.count(100)
# Out:
# 1

# %%
numeros_2.insert(3,6)
numeros_2
# Out:
# [10, 0, 10, 6, 6, 6, 100, 1000]
