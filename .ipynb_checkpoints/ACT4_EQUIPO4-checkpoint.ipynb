# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

data1 = np.loadtxt('dataset1.txt')
data3 = np.loadtxt('dataset3.txt')

with open('dataset1.txt', 'r') as f1, open('dataset3.txt', 'r') as f3 : #'r' es de read
    print(type(f1))
    print(type(f3))
    data1 = np.loadtxt(f1)
    data2 = np.loadtxt(f3)
print(data1.shape)
print(data1.size)
print(data3.shape)
print(data3.size)

#2. Extraccion de columnas
C1D1 = data1[:, 0]
C2D1 = data1[:, 1]
C1D3 = data3[:, 0]
C2D3 = data3[:, 1]

#3. Manejo de dif. tamaños
n = min(len(C1D1), len(C1D3))
n2 = min(len(C2D1), len(C2D3))
C1D1 = C1D1[:n]
C1D3 = C1D3[:n]
C2D1 = C2D1[:n2]
C2D3 = C2D3[:n2]

#4. Operaciones entre columnas
R1 = C1D1 + C1D3
R2 = C1D1 - C1D3
R3 = C1D1 * C1D3
texto = 'Promedio de data1'
R4 = np.mean(C1D1) 
texto2 = 'Promedio de data3'
R5 = np.mean(C1D3)
print(texto)
print(R4)
print(texto2)
print(R5)

#5. Graficación de columnas
plt.plot(C1D1, label='Data 1')
plt.plot(C1D3, label='Data 3')
plt.legend()
plt.grid()
plt.show()
# Out:
# <class '_io.TextIOWrapper'>
# <class '_io.TextIOWrapper'>
# (3250, 4)
# 13000
# (5000, 2)
# 10000
# 0.551439723076923
# 55.02536461538462
