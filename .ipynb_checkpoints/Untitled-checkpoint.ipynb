# %%
print("hola");
Var=5;
# Out:
# hola

# %%
Var2=10.5;

# %%
print(type(Var));
# Out:
# <class 'int'>

# %%
a=2

# %%
b=3

# %%
c=a+b

# %%
print(c)
# Out:
# 5

# %%
x=2**3
print(x)
y=10/3
z=10//3
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# 8
# 3.3333333333333335
# <class 'float'>
# 3
# <class 'int'>

# %%
num="554.5"
print(type(num))
num=float(num)
print(type(num))
num=int(num)
print(type(num))
print(num)
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# 554

# %%
num1=5567
num2=65.9
str1=str(num1)
str2=str(num2)
print(type(str1))
print(type(str2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
d=(5<=6)
print(d)
print(type(d))
# Out:
# True
# <class 'bool'>

# %%
a = True
b = False
d = False
c_state = False 
x = a or b
y = a and b

equation_1 = not (a and b) or not (a and c_state) or d
equation_2 = not (a and b and c_state) or (a and c_state and b) or a
equation_3 = not ((x or y) or (x and y))

print(f"Valores iniciales: A={a}, B={b}")
print(f"Valores calculados: X={x}, Y={y}")
print(f"Resultado Ecuacion 1: {equation_1}")
print(f"Resultado Ecuacion 2: {equation_2}")
print(f"Resultado Ecuacion 3: {equation_3}")
# Out:
# Valores iniciales: A=True, B=False
# Valores calculados: X=True, Y=False
# Resultado Ecuacion 1: True
# Resultado Ecuacion 2: True
# Resultado Ecuacion 3: False
