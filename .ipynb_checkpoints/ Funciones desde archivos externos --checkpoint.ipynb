# %%
from operaciones import suma, multiplicacion

resultado1 = suma(3, 4)

resultado2 = multiplicacion(5, 6)

print("Suma:", resultado1)

print("Multiplicación:", resultado2)

#Ejemplo 2
from utilidades import saludo
mensaje = saludo("Nuvix")
print(mensaje)

#Ejemplo 3
import numpy as np
import matplotlib.pyplot as plt
from regresion import lin_regresion

#Cargar datos desde archivo
# Usamos el nombre del archivo que tienes en tu carpeta
datos = np.loadtxt("datos_regresion.txt")

# Separar columnas (x, y)
x = datos[:, 0]
y = datos[:, 1]

# Calcular regresión
m, b = lin_regresion(x, y)
print("Pendiente (m):", m)
print("Intersección (b):", b)

# EL EJERCICIO PROPUESTO 

# 1. Calcular la recta (modelo ideal)
y_ideal = m * x + b

# 2. Graficar datos experimentales (scatter) y modelo (plot) en la misma figura
plt.figure(figsize=(8, 5))
plt.scatter(x, y, color='blue', label='Datos experimentales') 
plt.plot(x, y_ideal, color='red', label='Modelo ideal')

# 3. Formato de la gráfica
plt.title("Regresión Lineal")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)

# Mostrar gráfica
plt.show()
# Out:
# Suma: 7
# Multiplicación: 30
# Hola Nuvix
# Pendiente (m): 9.95086045836842
# Intersección (b): 5.737073613579105
